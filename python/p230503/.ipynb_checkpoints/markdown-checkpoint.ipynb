# %% [markdown]
# 마크 다운 형태 m 풀기 는 y 문서 형식으로 변경가능해요

# %% [markdown]
# # 헤딩 1
#
# ## 제목 2
#
# ### 제목 3
#
# ### 제목 4
#
# ### 제목 5
#
# #### 제목 6
# ####### 제목 *여기는 없어요

# %% [markdown]
# # 순서 없는 리스트
# - 순서 없는 리스트
# - 검정색 동그라미 하이픈 띄어쓰기
#     - 리스트2.1 탭 누르고 하이픈 띄어쓰기는 네모
#         - 리스트 2.1.1
#         - 리스트 2.1.2
#     - 리스트 2.2
# - 리스트

# %% [markdown]
# # 순서 있는 리스트
# 1. 리스트1 1로 쓰면 알아서 번호 부여를 해요
# 1. 리스트2
#     1. 리스트 2.1
#         1. 리스트 2.1.1 순서있는 리스트는 공백은 안되용 탭으로 해요
#         1. 리스트 2.1.2
#     1. 리스트 2.2
# 1. 리스트 3

# %% [markdown]
# # 글자 진하게
# **진하게 **굵게 <<< 띄어쓰기 안되고 붙여서 쓰고 엔터는 안되용

# %% [markdown]
# 하나 줄바꿈을 하고 싶으면 스페이스 두개
# 둘
# 셋

# %% [markdown]
# # 수평선

# %% [markdown]
# # 코드일 경우 ``` 세개를 쓴다
#
#
# ```python
# num =5
# print
# ```
#
# ```
# num =5
# print
# ```

# %% [markdown]
# # 인용구
# > 인용1
# > 인용2
# > 인용3
# >사용하고 두번띄어쓰기

# %% [markdown]
# # 표
# 이름 | 전화번호 | 이메일
# - | - | - |
# s|010|a@naver.com
# B|02|gmail.com
#
# 표 스타일은 가로선을 넣어주세요

# %% [markdown]
# # 이미지
# ![image.png](attachment:image.png) alt + PrtSc 붙여 넣기

# %% [markdown]
# # url
# - 참고자료
# - https://www.naver.com/

# %%
pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install
