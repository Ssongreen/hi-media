# %%
import requests
import json
import pandas as pd

headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}
url = "https://finance.naver.com/world/worldDayListJson.naver?symbol=SPI@SPX&fdtc=0&page="
data = []

for i in range(1,11):
    httpResponse = requests.get(f"{url}{i}", headers=headers)
    print(httpResponse.status_code)
#   data = json.loads(httpResponse.text)         방법1
    data.extend(httpResponse.json())             #방법2
#     data += httpResponse.json()
table = pd.DataFrame(data)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 13
#      11     print(httpResponse.status_code)
#      12 #   data = json.loads(httpResponse.text)         방법1
# ---> 13 data.extend(httpResponse.json())             #방법2
#      14 #     data += httpResponse.json()
#      15 table = pd.json_normalize(data)
#
# NameError: name 'data' is not defined

# %%
table
# Out:
#         symb      xymd     open     high      low     clos   diff  rate
# 0    SPI@SPX  20221214  4015.54  4053.76  3965.65  3995.32 -24.33 -0.61  \
# 1    SPI@SPX  20221213  4069.38  4100.96  3993.03  4019.65  29.09  0.73
# 2    SPI@SPX  20221212  3939.29  3990.71  3935.30  3990.56  56.18  1.43
# 3    SPI@SPX  20221209  3954.17  3977.02  3933.04  3934.38 -29.13 -0.73
# 4    SPI@SPX  20221208  3947.79  3974.19  3935.83  3963.51  29.59  0.75
# ..       ...       ...      ...      ...      ...      ...    ...   ...
# 205  SPI@SPX  20221207  3933.28  3957.57  3922.68  3933.92  -7.34 -0.19
# 206  SPI@SPX  20221206  3996.63  4001.51  3918.39  3941.26 -57.58 -1.44
# 207  SPI@SPX  20221205  4052.02  4052.45  3984.49  3998.84 -72.86 -1.79
# 208  SPI@SPX  20221202  4040.17  4080.48  4026.63  4071.70  -4.87 -0.12
# 209  SPI@SPX  20221201  4087.14  4100.51  4050.87  4076.57  -3.54 -0.09
#
#            gvol
# 0    2603890540
# 1    3087952330
# 2    2285904830
# 3    2123231340
# 4    2157778240
# ..          ...
# 205  2263753220
# 206  2367140660
# 207  2278161210
# 208  2076416490
# 209  2319414990
#
# [210 rows x 9 columns]

# %%
table.to_csv("naver_sise.csv", index=False)
print("저장??")
# Out:
# 저장??
