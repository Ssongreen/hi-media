# %%
"""
1 - 10page(200개) 뉴스 타이틀을 화면에 출력하기.
- 출력 형태 :1. 타이틀 

"""
import json
import requests
from bs4 import BeautifulSoup 
import pandas as pd

# %%
headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}

json_url = "https://news.naver.com/main/mainNews.naver?sid1=101&date=%2000:00:00:00&page=1"
news_title = []
for i in range(1,11):
    alls = requests.get(f"{json_url}{i}", headers = headers)
    news =alls.json()
    news_page = json.loads(news["airsResult"])["result"]["101"]
    news_title.extend(news_page)
news_title

for idx, new_line in enumerate(news_title, 1):
    print(f"{idx}.{new_line['title']}")


table = pd.DataFrame(new_title)
table
# Out:
# [{'sectionId': '101',
#   'gdid': '88000108_000000000000000004184482',
#   'articleId': '0004184482',
#   'officeId': '011',
#   'officeName': '서울경제',
#   'title': '금감원, 2차 경력직원 채용',
#   'summary': '금융감독원은 다음달 12일까지 올해 두번째 경력직원(외부전문인력) 채용 원서를 접수한다고 28일 밝혔다. 앞서 지난 2월부터 진행한 첫 경력직 채용 결과는 5월 중 발표된다. 금감원은 최종 합격자 15명을 발표할 예',
#   'serviceTime': 1682643673000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/011/2023/04/28/4184482.jpg',
#   'type': '1',
#   'sessionId': 'K2yuRo4GrqMFpW3o',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000385_000000000000000005252233',
#   'articleId': '0005252233',
#   'officeId': '277',
#   'officeName': '아시아경제',
#   'title': 'SK바사, 27년까지 2.4조원 쏟아붓는다…"바이오 강국 이뤄낼 것"',
#   'summary': '"지금부터 5년이 SK바이오사이언스의 미래를 좌우할 적극적 투자의 시기입니다. 신속하고 체계적으로 성장해 나갈 것을 약속드리겠습니다." 안재용 SK바이오사이언스 사장은 28일 오전 서울 중구 한국프레스센터에서 열린 ',
#   'serviceTime': 1682643671000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/277/2023/04/28/5252233.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000FF_000000000000000005004269',
#   'articleId': '0005004269',
#   'officeId': '014',
#   'officeName': '파이낸셜뉴스',
#   'title': '"벌써 더운 날씨" SK매직, 원코크 얼음물 정수기 공개',
#   'summary': "SK매직이 하나의 코크에서 얼음과 물을 동시에 출수할 수 있는 '원코크 얼음물 정수기'를 선보였다. 28일 SK매직에 따르면 원코크 얼음물 정수기 출시와 함께 렌털료 할인 등 프로모션을 다음 달 1일부터 진행한다. ",
#   'serviceTime': 1682643671000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/014/2023/04/28/5004269.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000FF_000000000000000005004268',
#   'articleId': '0005004268',
#   'officeId': '014',
#   'officeName': '파이낸셜뉴스',
#   'title': '"서민도 낸다"...부동산 급등에 상속·증여세 30만 육박',
#   'summary': "부동산 가격 급등으로 최근 상속·증여세 납부 대상이 80% 이상 늘었다. 서민·중산층이 예기치 못한 상속·증여세 납부 대상이 돼 고민이 늘자 국세청이 '상속·증여 세금 상식'을 쉽게 알리기로 했다. 국세청은 상속세 ",
#   'serviceTime': 1682643667000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/014/2023/04/28/5004268.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000385_000000000000000005252232',
#   'articleId': '0005252232',
#   'officeId': '277',
#   'officeName': '아시아경제',
#   'title': '협동조합형 민간임대 아파트 ‘천안역 더브리즈’, 조합원 모집 임박',
#   'summary': '천안시 서북구 성정동 일원에 협동조합형 민간임대 아파트인 ‘천안역 더브리즈’가 추진돼 새로운 주거 대안으로 주목 받고 있다. 해당 사업지는 우리자산신탁으로 100% 토지 등기가 완료된 상태로 우리자산신탁의 토지사용동',
#   'serviceTime': 1682643666000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/277/2023/04/28/5252232.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000107_000000000000000004838435',
#   'articleId': '0004838435',
#   'officeId': '015',
#   'officeName': '한국경제',
#   'title': "'SG증권發' 대량매도' 연루 종목들, 하한가 탈출…일부는 '상승'",
#   'summary': '외국계 증권사 소시에테제네랄(SG)증권에서 매물이 대량으로 나오며 연일 급락세를 탔던 종목들이 28일 하한가에서 벗어났다. 이날 한국거래소에 따르면 오전 9시 48분 기준 선광은 전일 대비 4550원(11.26%) ',
#   'serviceTime': 1682643666000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/015/2023/04/28/4838435.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000C2_000000000000000004881085',
#   'articleId': '0004881085',
#   'officeId': '008',
#   'officeName': '머니투데이',
#   'title': "[단독]'주가조작 창구' 의심 실내골프장, 노홍철 건물에 입주-셀럽주식방 게이트",
#   'summary': 'SG증권발 셀럽 주식방 게이트에서 투자자 모집과 수수료 편취 수단으로 활용됐다는 의혹을 받는 강남 실내골프연습장이 방송인 노홍철 소유 건물에 위치한 것으로 확인됐다. 노홍철 소속사는 노홍철이 주가조작 일당으로부터 투',
#   'serviceTime': 1682643618000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/008/2023/04/28/4881085.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D8_000000000000000013909767',
#   'articleId': '0013909767',
#   'officeId': '001',
#   'officeName': '연합뉴스',
#   'title': "LG전자, 고양국제꽃박람회서 '틔운 팝업스토어' 운영",
#   'summary': "LG전자는 내달 8일까지 경기도 고양 일산호수공원에서 열리는 고양국제꽃박람회에서 식물생활가전 'LG 틔운·틔운 미니 팝업스토어'를 운영한다고 28일 밝혔다. 국내 최대 규모 꽃 축제인 고양국제꽃박람회는 코로나19 이",
#   'serviceTime': 1682643605000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/001/2023/04/28/13909767.jpg',
#   'type': '1',
#   'sessionId': 'K2yuRo4GrqMFpW3o',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005474336',
#   'articleId': '0005474336',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': "5월, 청약시장 '국지적 훈풍'에 전국 2만여 가구 공급",
#   'summary': '5월 전국적으로 2만여 가구가 분양시장에 나올 전망이다. 정부의 대대적인 규제 완화 정책에 힘입어 서울 분양시장에 온기가 감돌고, 일부 지방 분양 아파트에도 수천개의 청약통장이 몰리는 등 국지적으로 분양 시장이 활기',
#   'serviceTime': 1682643603000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/28/5474336.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880002EC_000000000000000000044095',
#   'articleId': '0000044095',
#   'officeId': '243',
#   'officeName': '이코노미스트',
#   'title': '전두환 손자 전우원 ‘마약 혐의’ 검찰 송치',
#   'summary': '서울경찰청 마약범죄수사대는 각종 마약을 투약한 혐의로 전두환 전 대통령의 손자 전우원(27)씨를 28일 불구속 송치했다. 경찰에 따르면 전씨는 미국에 체류하며 복수의 마약류를 투약한 혐의(마약류관리법 위반)를 받는다',
#   'serviceTime': 1682643601000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/243/2023/04/28/44095.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011830079',
#   'articleId': '0011830079',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': '노동부·금감원 "퇴직연금, 노후소득의 보루"…수익률 제고 노력 당부',
#   'summary': '기사내용 요약 퇴직연금 사업 금융기관 방문 간담회 개최 고용노동부와 금융감독원이 "퇴직연금은 근로자 노후소득의 보루"라고 강조하며 퇴직연금 사업자의 사회적 책무 및 서비스 혁신을 당부했다. 또 퇴직연금 상품의 수익률',
#   'serviceTime': 1682643600000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/28/11830079.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011830078',
#   'articleId': '0011830078',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': '금감원, 경력직 2차 채용 접수…회계사·IT·검사 분야',
#   'summary': '금융감독원은 다음달 12일까지 경력직원(외부전문인력) 채용을 진행한다고 28일 밝혔다. 이는 올해 두 번째 경력직 채용으로 지난 2월부터 진행한 1차 경력 채용은 다음달 중 최종 합격자 15명을 발표할 예정이다. 모',
#   'serviceTime': 1682643600000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/28/11830078.jpg',
#   'type': '1',
#   'sessionId': 'gqgaQ8sWPZMkRZa7',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000C2_000000000000000004881081',
#   'articleId': '0004881081',
#   'officeId': '008',
#   'officeName': '머니투데이',
#   'title': '갑작스러운 상속세?…당황하지 마세요, 국세청이 알려드려요',
#   'summary': "국세청이 부동산 가격 상승 등으로 예기치 못하게 상속세나 증여세 납부대상이 될 수 있어 걱정하는 국민을 위해 상속·증여에 관한 세금 상식을 소개한다. 국세청은 28일 이 같은 내용이 담긴 '상속·증여 세금 상식'을 ",
#   'serviceTime': 1682643600000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/008/2023/04/28/4881081.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D8_000000000000000013909757',
#   'articleId': '0013909757',
#   'officeId': '001',
#   'officeName': '연합뉴스',
#   'title': '금감원, 증권사 긴급소집…"CFD 등 레버리지 투자 리스크 관리"',
#   'summary': "'무더기 하한가 사태' 이후 현안 공유…CFD 관련 고객 유치 자제령 CFD 잔고 작년 말 대비 52% 급증…대차찬고도 역대 최대 금융감독원이 증권사 사장들을 긴급 소집해 '무더기 하한가 사태'의 진원지로 지목된 차",
#   'serviceTime': 1682643600000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/001/2023/04/28/13909757.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011830081',
#   'articleId': '0011830081',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': '상속·증여세도 보편세금…납부대상 4년새 80% 이상 증가',
#   'summary': "기사내용 요약 국세청 '상속·증여 세금 상식' 제작·배포 국세청은 부동산 가격 상승 등으로 예기치 못하게 상속세 및 증여세 납부대상이 될 가능성이 생겨 걱정하고 있는 국민을 위해 처음으로 '상속·증여 세금 상식'을 ",
#   'serviceTime': 1682643600000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/28/11830081.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000F1_000000000000000002303904',
#   'articleId': '0002303904',
#   'officeId': '123',
#   'officeName': '조세일보',
#   'title': "1분기 승용차 수출 154억달러…분기 기준 '역대 최대'",
#   'summary': '2023년 1분기 승용차 수출액은 154억달러로 전년동기대비 41.1% 증가하며 분기 기준 역대 최대 실적을 달성했다. 친환경 승용차도 68.4% 늘며 지난해 4분기 기록을 넘어섰다. 28일 관세청에 따르면, 1분기',
#   'serviceTime': 1682643541000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/123/2023/04/28/2303904.jpg',
#   'type': '1',
#   'sessionId': 'ax2o4ZlDsGYgIjwI',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D6_000000000000000000743646',
#   'articleId': '0000743646',
#   'officeId': '031',
#   'officeName': '아이뉴스24',
#   'title': '인텔, 1분기 사상 최악 실적···"2분기도 어렵다"',
#   'summary': '미국 최대 반도체 기업인 인텔이 PC 시장 침체로 1분기 사상 최악의 성적표를 받았다. 당기순손실 규모만 약 4조원으로 6년 만에 최대 규모의 적자를 냈다. 27일(현지시간) 인텔은 1분기에 매출 117억 달러(약 ',
#   'serviceTime': 1682643541000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/031/2023/04/28/743646.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D8_000000000000000013909754',
#   'articleId': '0013909754',
#   'officeId': '001',
#   'officeName': '연합뉴스',
#   'title': '대웅제약 "2형 당뇨병 신약 \'엔블로정\' 다음달 1일 출시"',
#   'summary': "대웅제약은 자체 개발한 2형 당뇨병 치료제 '엔블로정'을 다음 달 1일 국내에 출시한다고 28일 밝혔다. 엔블로정은 지난 25일 보건복지부 고시에 따라 당뇨병 용제로서 약제 급여 목록에 등재됐다. 적응증(치료범위)은",
#   'serviceTime': 1682643536000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/001/2023/04/28/13909754.jpg',
#   'type': '1',
#   'sessionId': 'FdYlZBy9ojDJ7S2A',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011830074',
#   'articleId': '0011830074',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': "얼음과 물 동시에…SK매직 '원코크 얼음물 정수기' 출시",
#   'summary': "기사내용 요약 하루 최대 600개 얼음·대 아이스룸 직수·스테인레스 재질…'4중 안심케어' [서울=뉴시스]권안나 기자 = SK매직이 국내 최초로 하나의 코크에서 얼음과 물이 동시에 출수되는 '원코크 얼음물 정수기'를",
#   'serviceTime': 1682643520000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/28/11830074.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880003A5_000000000000000000043760',
#   'articleId': '0000043760',
#   'officeId': '293',
#   'officeName': '블로터',
#   'title': '테슬라 신형 모델 X, 일반 스티어링 휠도 최상의 선택 [시승기]',
#   'summary': '테슬라 신형 모델 S나 모델 X에 탑재된 요크 스티어링 휠(운전대)이 두려운 운전자라면, 일반 스티어링 휠을 선택하는 것을 강력 추천한다. 일반 스티어링 휠은 조향의 편의성을 제공할 뿐만 아니라 차량의 디지털 클러스',
#   'serviceTime': 1682643481000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/293/2023/04/28/43760.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '08138263_000000000000000006775999',
#   'articleId': '0006775999',
#   'officeId': '421',
#   'officeName': '뉴스1',
#   'title': '원희룡 "전세사기 피해 정부 직접지원, 다른 민간 피해자들과 형평성 어긋나"',
#   'summary': '원희룡 국토교통부 장관이 IMF 외환위기 때 회사의 부실채권을 인수한 기준으로 정부가 전세사기 보증금을 보상할 경우 지원금이 10% 수준에 머물고, 헌법상으로도 불가능할뿐더러 민간거래에서 사기당한 많은 피해자들과의 ',
#   'serviceTime': 1682643444000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/421/2023/04/28/6775999.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800010E_000000000000000002136579',
#   'articleId': '0002136579',
#   'officeId': '016',
#   'officeName': '헤럴드경제',
#   'title': '5월 증시 키워드는 美 부채한도, 高밸류에이션, 개인 수급 …“코스피 숨고르기” [투자360]',
#   'summary': '증권가는 5월 증시가 가파른 상승세를 멈추고 잠시 쉬어가는 모습을 보일 것으로 전망했다. 미국 연방정부의 부채 한도를 둘러싼 공방과 높은 밸류에이션이 시장을 압박할 것이란 판단이다. 한편, 최근 유입된 개인 투자자들',
#   'serviceTime': 1682643423000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/016/2023/04/28/2136579.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005474329',
#   'articleId': '0005474329',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': 'DL이앤씨, 1분기 매출 1.8조원·신규수주 3.2조원 달성',
#   'summary': 'DL이앤씨가 올해 1분기 매출액 1조8500억원, 신규수주 3조2762억원을 달성했다. 다만 부동산 침체에 수익성이 약화됐다. DL 사옥 D타워 돈의문 (사진=DL이앤씨) DL이앤씨는 28일 잠정 실적발표를 통해 연',
#   'serviceTime': 1682643422000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/28/5474329.jpg',
#   'type': '1',
#   'sessionId': 'R8fqvJPDN0Dm0OPU',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8822bt5c_000000000000000000000866',
#   'articleId': '0000000866',
#   'officeId': '665',
#   'officeName': '더스쿠프',
#   'title': "0.3㎜ 바늘에 '미용 기술' 심은 이 업체의 DNA [컴퍼니+]",
#   'summary': "고령화, SNS의 발달, 여성의 경제력 상승, 미용에 관심 갖는 남성의 증가…. 각기 다른 이 현상들은 미용기기 시장의 성장을 이끄는 원동력이다. 시장이 미용기기 전문기업 '비올'을 주목하는 이유도 여기에 있다. 비",
#   'serviceTime': 1682643421000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/665/2023/04/28/866.jpg',
#   'type': '1',
#   'sessionId': 'LfnsFAUu1SQUJA1z',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000119_000000000000000001269424',
#   'articleId': '0001269424',
#   'officeId': '214',
#   'officeName': 'MBC',
#   'title': '난감한 삼성·SK‥적자 충격 안고 미·중 격랑 속으로',
#   'summary': '최근 경제계 소식 중에 삼성전자와 SK하이닉스의 올해 1분기 실적이 단연 화두입니다. 많은 언론이 ‘사상 최악’ ‘반도체 적자 쇼크’ 같은 제목으로 기사를 썼습니다. 삼성은 반도체 부문에서 약 4조 6천억 원 적자,',
#   'serviceTime': 1682643397000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/214/2023/04/28/1269424.jpg',
#   'type': '1',
#   'sessionId': 'ax2o4ZlDsGYgIjwI',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000AD_000000000000000002797611',
#   'articleId': '0002797611',
#   'officeId': '029',
#   'officeName': '디지털타임스',
#   'title': '호수 품은 `군산 한라비발디 더프라임`, 견본주택 28일 개관',
#   'summary': "5월 8일 특별공급을 시작으로 9일부터 1순위 청약, 당첨자 발표는 16일 HL 디앤아이한라㈜는 '군산 한라비발디 더프라임' 견본주택을 오늘(28일) 오픈하고 본적적인 분양에 나선다. 이 단지는 지하 3층~지상 29",
#   'serviceTime': 1682643367000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/029/2023/04/28/2797611.jpg',
#   'type': '1',
#   'sessionId': 'ax2o4ZlDsGYgIjwI',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005474327',
#   'articleId': '0005474327',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': "증권사들, '무더기 하한가 사태' 주범 CFD 신규 가입·매매 차단",
#   'summary': '소시에테제네랄(SG)증권발(發) 무더기 하한가 사태의 진원지가 된 차액결제거래(CFD)에 대해 관련 서비스를 제공하는 증권사들이 신규 가입과 매매를 중단하고 있다. 일부 증권사는 SG증권 창구에서 쏟아진 8개 종목과',
#   'serviceTime': 1682643362000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/28/5474327.jpg',
#   'type': '1',
#   'sessionId': 'ax2o4ZlDsGYgIjwI',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000107_000000000000000004838432',
#   'articleId': '0004838432',
#   'officeId': '015',
#   'officeName': '한국경제',
#   'title': '법적 분쟁 일단락 된 부산 남천2구역…사업 속도 내나',
#   'summary': '부산 재건축 최대어로 꼽히는 수영구 남천동 ‘삼익비치타운(남천2구역)’의 설계업체 변경을 둘러싼 조합과 건축사사무소 사이 법적 분쟁이 일단락됐다. 조합 측이 두 건의 가처분 소송에서 연달아 승기를 잡으면서 사업 속도',
#   'serviceTime': 1682643303000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/015/2023/04/28/4838432.jpg',
#   'type': '1',
#   'sessionId': 'ax2o4ZlDsGYgIjwI',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005474325',
#   'articleId': '0005474325',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': '시몬스, 동종업체 이직한 전 직원에 ‘전직금지 가처분’ 소송',
#   'summary': '시몬스 침대가 동종업체로 이직한 전 직원을 상대로 법적조치에 나섰다. 기밀유지를 위해 작성하는 동종업계 이직 금지 서약을 어겼다는 이유에서다. 시몬스 R&D센터에서 테스트를 진행하는 모습. (사진=시몬스) 시몬스는 ',
#   'serviceTime': 1682643303000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/28/5474325.jpg',
#   'type': '1',
#   'sessionId': 'ax2o4ZlDsGYgIjwI',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000149_000000000000000001098371',
#   'articleId': '0001098371',
#   'officeId': '215',
#   'officeName': '한국경제TV',
#   'title': "대웅제약, 2형 당뇨병 신약 '엔블로정' 내달 1일 출시",
#   'summary': "대웅제약은 자체 개발 2형 당뇨병 치료제 '엔블로정'이 오는 5월1일 국내 출시한다. 28일 대웅제약은 지난 25일 보건복지부 고시에 따라 자체 개발 신약 엔블로정 0.3mg(성분명 : 이나보글리플로진, Enavog",
#   'serviceTime': 1682643267000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/215/2023/04/28/1098371.jpg',
#   'type': '1',
#   'sessionId': 'ydwsDzuXyYJFXc9G',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D1_000000000000000003357315',
#   'articleId': '0003357315',
#   'officeId': '081',
#   'officeName': '서울신문',
#   'title': 'LGU+ ‘접속장애’ 개인고객에 10배 요금 감면·PC방 현금 보상',
#   'summary': '올해 초 두 차례 접속 장애가 발생한 LG유플러스가 자사 서비스 이용에 불편을 겪은 개인 고객에게 장애 시간 10배의 요금을 감면한다. PC방 사업자에게는 현금으로 보상하거나 요금을 감면한다. 28일 LG유플러스가 ',
#   'serviceTime': 1682643241000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/081/2023/04/28/3357315.jpg',
#   'type': '1',
#   'sessionId': 'b2nWPqbJTHx5m9DQ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8812A0A8_000000000000000002707652',
#   'articleId': '0002707652',
#   'officeId': '119',
#   'officeName': '데일리안',
#   'title': '결혼 연령 늦춰지면서 ‘조카바보’ 늘었다',
#   'summary': '롯데멤버스가 라임(Lime) 가정의 달 선물 계획 설문 조사 결과를 바탕으로 ‘지금, 우리는’ 뉴스레터를 발행했다. 라임은 전국 38만여 명의 패널을 보유한 롯데멤버스 자체 리서치 플랫폼이다. 조사 결과, 응답자 2',
#   'serviceTime': 1682643181000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/119/2023/04/28/2707652.jpg',
#   'type': '1',
#   'sessionId': 'b2nWPqbJTHx5m9DQ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000149_000000000000000001098369',
#   'articleId': '0001098369',
#   'officeId': '215',
#   'officeName': '한국경제TV',
#   'title': '오비맥주 카스, 1분기 가정시장 맥주 1위..."하루 700만병 팔려"',
#   'summary': '오비맥주는 카스가 올해 1분기 코로나19 사태 이후 분기별 최고 점유율을 기록했다고 28일 밝혔다. 시장조사기관 닐슨코리아에 따르면 올 1분기 가정시장에서 카스는 약 42.8% 점유율로 1위를 달성했다. 이는 201',
#   'serviceTime': 1682643157000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/215/2023/04/28/1098369.jpg',
#   'type': '1',
#   'sessionId': 'ydwsDzuXyYJFXc9G',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011830043',
#   'articleId': '0011830043',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': "'SG發' 하한가 멈췄나…8개 중 6개 종목 반등",
#   'summary': '기사내용 요약 선광·대성홀딩스 제외 나머지는 상승세 전환 [서울=뉴시스] 박은비 기자 = 소시에테제네랄(SG)증권 창구에서 쏟아져 나온 매물로 급락했던 8개 종목 중에서 6개 종목이 반등에 성공했다. 선광과 대성홀딩',
#   'serviceTime': 1682643130000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/28/11830043.jpg',
#   'type': '1',
#   'sessionId': 'kAIF1YLFLVK4qjeR',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D6_000000000000000000743643',
#   'articleId': '0000743643',
#   'officeId': '031',
#   'officeName': '아이뉴스24',
#   'title': "'알리'부터 '큐텐'까지...해외직구 이커머스 한국 시장 공략 강화",
#   'summary': '한국에 진출하는 해외직구 기업들이 늘고 있다. 이들 기업들은 국내 이커머스 회사를 인수합병하거나, 전용물류단지를 구축하는 등 한국 시장에 공격적 투자를 이어가고 있다. 28일 최근 발표된 관세청의 2022년 해외직구',
#   'serviceTime': 1682643121000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/031/2023/04/28/743643.jpg',
#   'type': '1',
#   'sessionId': 'b2nWPqbJTHx5m9DQ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '08138263_000000000000000006775975',
#   'articleId': '0006775975',
#   'officeId': '421',
#   'officeName': '뉴스1',
#   'title': "삼천리·세방 '반등', 선광·대성도 하한가 풀려…'하따' 경고음",
#   'summary': '지난 24일 무더기 하한가를 맞은 이후 4거래일 연속 하한가를 이어왔던 종목들이 5일째인 28일에 하한가를 면했다. 삼천리(004690) 세방(004360) 등은 반등하는 모습도 보이고 있다. 다만 외국인과 기관의 ',
#   'serviceTime': 1682643111000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/421/2023/04/28/6775975.jpg',
#   'type': '1',
#   'sessionId': 'b2nWPqbJTHx5m9DQ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8812805E_000000000000000000916779',
#   'articleId': '0000916779',
#   'officeId': '417',
#   'officeName': '머니S',
#   'title': '대웅제약, 美 기업에 자가면역질환 신약 6400억원 규모 기술수출',
#   'summary': "대웅제약이 자가면역질환 신약 후보물질을 미국 바이오 기업에 기술수출했다. 대웅제약은 지난 27일(현지시각) 미국 보스턴에서 열린 '한·미 디지털·바이오헬스 비즈니스 포럼'에서 미국 생명공학 투자회사 애디텀바이오의 자",
#   'serviceTime': 1682643072000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/417/2023/04/28/916779.jpg',
#   'type': '1',
#   'sessionId': 'b2nWPqbJTHx5m9DQ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000385_000000000000000005252222',
#   'articleId': '0005252222',
#   'officeId': '277',
#   'officeName': '아시아경제',
#   'title': '보증금 걱정 없는 민간임대 아파트 ‘안성 영무예다음’',
#   'summary': '최근 전세사기 대한 주거불안이 높아지면서 가격 부담이 적고, 안정적으로 거주할 수 있는 민간임대 아파트에 관심이 쏠리고 있다. 주택도시보증공사 자료를 살펴보면, 임대사업자의 보증보험 가입 주택 가운데 절반 이상인 3',
#   'serviceTime': 1682643068000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/277/2023/04/28/5252222.jpg',
#   'type': '1',
#   'sessionId': 'R8fqvJPDN0Dm0OPU',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800010E_000000000000000002136572',
#   'articleId': '0002136572',
#   'officeId': '016',
#   'officeName': '헤럴드경제',
#   'title': '충당금 쌓고 이자익 줄었는데도…4대 금융지주, 올 1분기 영업익 삼성전자 제쳤다[머니뭐니]',
#   'summary': '4대 금융지주가 올 1분기에도 5조원에 가까운 당기순이익을 내며 돈을 쓸어 담았다. 예대마진 축소, 대규모 충당금 편입, 고금리 등에도 시장의 예상을 뒤집고 역대급 순이익을 다시 썼다. 1분기 효자 노릇을 한 건 유',
#   'serviceTime': 1682643066000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/016/2023/04/28/2136572.jpg',
#   'type': '1',
#   'sessionId': 'R8fqvJPDN0Dm0OPU',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8812805E_000000000000000000916778',
#   'articleId': '0000916778',
#   'officeId': '417',
#   'officeName': '머니S',
#   'title': '"KB스타뱅킹, 신한 쏠보다 더 쓰네" 은행 앱 MAU 경쟁 후끈',
#   'summary': '국내 4대 금융지주가 올 1분기 실적발표에서 디지털 전환의 성과를 핵심으로 내세웠다. 인터넷뱅킹과 모바일을 통한 비대면 금융 거래가 일상화하면서 각 금융지주 회장들은 금융 플랫폼의 경쟁력을 강화하는데 사활을 걸고 있',
#   'serviceTime': 1682643016000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/417/2023/04/28/916778.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880002EC_000000000000000000044093',
#   'articleId': '0000044093',
#   'officeId': '243',
#   'officeName': '이코노미스트',
#   'title': '전세로 살던 집, 경매로 넘어간다면?[경매TALK]',
#   'summary': '‘전세사기’ 또는 ‘깡통전세’가 사회문제로 확산되면서 주택이 경매로 넘어가더라도 임차인이 전세보증금을 지킬 수 있는 방안에 대한 논의가 활발하다. 특히 전세가율(주택가격 대비 전세보증금 비율)이 높은 다세대·연립 임',
#   'serviceTime': 1682643001000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/243/2023/04/28/44093.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000EA_000000000000000003094972',
#   'articleId': '0003094972',
#   'officeId': '030',
#   'officeName': '전자신문',
#   'title': '[ET라씨로] LG생활건강, 1분기 영업익 1459억원...실적 부진에 주가 약세',
#   'summary': "ET라씨로는 인공지능(AI) 기반으로 선별·분석한 주식 정보와 종목 매매 신호를 제공하는 전자신문 증권 정보 애플리케이션입니다. 플레이스토어에서 'ET라씨로'(->바로가기)를 다운로드하면 IT기업 뉴스와 시장 현황,",
#   'serviceTime': 1682643001000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/030/2023/04/28/3094972.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000ED_000000000000000003760627',
#   'articleId': '0003760627',
#   'officeId': '023',
#   'officeName': '조선일보',
#   'title': '현대차, 2023 캐스퍼 출시',
#   'summary': '현대차는 경형 SUV ‘2023 캐스퍼’를 27일 출시하고 공식 판매를 시작했다. 신형 캐스퍼에는 실용성을 강조한 차급이 새로 생기고 외장 색상도 추가됐다. 신형 캐스퍼에 추가된 ‘디 에센셜 라이트’ 차급에는 옵션으',
#   'serviceTime': 1682643001000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/023/2023/04/28/3760627.jpg',
#   'type': '1',
#   'sessionId': 'KucaBjOAeBl83ERG',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000FF_000000000000000005004256',
#   'articleId': '0005004256',
#   'officeId': '014',
#   'officeName': '파이낸셜뉴스',
#   'title': "美 SEC-거래소, 가상자산 '갑론을박'...'증권 vs 상품'",
#   'summary': '미국 금융 당국과 가상자산 업계가 가상자산의 법적인 정체성을 두고 치열한 논쟁을 벌이고 있다. 당국에서는 가상자산이 ‘증권’이라며 거래소가 증권거래소로 등록하지 않으면 제재하겠다고 경고했고 거래소들은 자신들이 증권 ',
#   'serviceTime': 1682642884000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/014/2023/04/28/5004256.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011830025',
#   'articleId': '0011830025',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': '반도체 기저효과에 생산 1년만에 최대폭↑…"경기 둔화세 지속"(종합2보)',
#   'summary': '기사내용 요약 통계청, 2023년 3월 산업활동동향 발표 생산 1.6%·소비 0.4%↑…투자는 2.2%↓ "전반적인 수치 변동에도 아직은 부진" [세종=뉴시스]용윤신 임하은 기자 = 기저효과 등으로 지난달 반도체 생',
#   'serviceTime': 1682642835000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/28/11830025.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000108_000000000000000004184469',
#   'articleId': '0004184469',
#   'officeId': '011',
#   'officeName': '서울경제',
#   'title': '포스코그룹, 철강·리튬 부산물로 도자기 만든다',
#   'summary': '포스코그룹이 철강과 리튬 생산 과정에서 나오는 부산물을 활용해 도자·공예산업 활성화를 지원한다. 27일 포스코는 이천시, 한국세라믹기술원과 도자기 분야에서 소재 공급을 위한 협력체계를 구축하는 업무협약을 체결했다고 ',
#   'serviceTime': 1682642821000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/011/2023/04/28/4184469.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000BF_000000000000000001738795',
#   'articleId': '0001738795',
#   'officeId': '057',
#   'officeName': 'MBN',
#   'title': '경매자금 전액 대출·취득세 면제…보증금 채권 매입 빠졌다',
#   'summary': '전세사기 피해자 지원을 위한 특별법 내용이 공개됐습니다. 예고했던 대로 우선매수권을 부여하고 경매자금도 낮은 금리로 전액 대출받을 수 있게 했는데, 피해자들 반응은 차갑습니다. 인정받기 위한 요건이 여섯 가지나 되고',
#   'serviceTime': 1682642821000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/057/2023/04/28/1738795.jpg',
#   'type': '2',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000385_000000000000000005252216',
#   'articleId': '0005252216',
#   'officeId': '277',
#   'officeName': '아시아경제',
#   'title': "코로나에도 치킨집 3만개 돌파…'月 1억' 매출 찍은 지역은?",
#   'summary': '코로나 사태에도 치킨집 수가 꾸준히 늘어 지난해 전국 3만개를 돌파했다. 하지만 월평균 매출은 코로나 전인 2019년 1082만원에서 지난해 700만원 이하로 떨어졌다. 치킨집 창업 시장의 경쟁이 심화되는 모습이다.',
#   'serviceTime': 1682642770000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/277/2023/04/28/5252216.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800010E_000000000000000002136564',
#   'articleId': '0002136564',
#   'officeId': '016',
#   'officeName': '헤럴드경제',
#   'title': '회계제도 변경에 보험사 웃었다…두자릿수 이상 성장[머니뭐니]',
#   'summary': '보험사들이 올해 회계기준(IFRS17) 변경 이후 첫 성적표를 받아들기 시작했다. IFRS17 적용에 따른 실적 개선 효과가 나타나며 전반적으로 두자릿수 이상의 견조한 성장세를 기록했다. 특히 IFRS17에서 유리한',
#   'serviceTime': 1682642761000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/016/2023/04/28/2136564.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8812A0A8_000000000000000002707643',
#   'articleId': '0002707643',
#   'officeId': '119',
#   'officeName': '데일리안',
#   'title': '헷갈리는 수하물 규정… "대한항공이 알려드릴게요"',
#   'summary': '#1 코로나19 팬데믹 이후 3년여만에 해외여행을 떠나는 A씨는 출발부터 불편함을 겪었다. 전자담배를 깜빡하고 부치는 가방안에 넣었기 때문. 공항 직원의 연락을 받고 수하물 검사실을 찾아야 했고, 그 곳에서 가방을 ',
#   'serviceTime': 1682642761000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/119/2023/04/28/2707643.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8817cacd_000000000000000000056790',
#   'articleId': '0000056790',
#   'officeId': '586',
#   'officeName': '시사저널',
#   'title': "김익래 다우키움 회장 'SG사태'로 폭락 전 지분 매각 논란",
#   'summary': '금융당국 "조사 착수 예정"…다우키움 "SG사태와 무관" 주가조작 세력에 의해 하한가 종목이 속출한 \'SG사태\'가 불거진 가운데 김익래 다우키움그룹 회장이 보유 주식을 폭락 직전 처분해 논란이 일고 있다. 27일 금',
#   'serviceTime': 1682642761000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/586/2023/04/28/56790.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8811AD97_000000000000000000333642',
#   'articleId': '0000333642',
#   'officeId': '374',
#   'officeName': 'SBS Biz',
#   'title': "[하우머니] '전세사기' 혼돈의 부동산…7월에 위기온다?",
#   'summary': "■ 재테크 노하우 100분 머니쇼 '하우머니' - 송승현 도시와경제 대표 Q. 정부가 어제(27일) 전세 사기 피해자 특별법 내용을 발표했습니다. 큰 줄기는 주거 안정을 위해 우선매수권이나 경매자금 대출을 해주는 것",
#   'serviceTime': 1682642707000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/374/2023/04/28/333642.jpg',
#   'type': '2',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8811AD97_000000000000000000333641',
#   'articleId': '0000333641',
#   'officeId': '374',
#   'officeName': 'SBS Biz',
#   'title': '美안보보좌관 "IRA 핵심광물 조항 불충분"',
#   'summary': '제이크 설리번 미국 백악관 국가안보보좌관은 현지시간 27일 미국 핵심광물 분야의 유연성 있는 공급망 구축과 관련, 인플레이션 감축법(IRA)의 인센티브 조항으로는 불충분하다며 추가조치를 예고했습니다. 미국은 지난해에',
#   'serviceTime': 1682642703000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/374/2023/04/28/333641.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000FF_000000000000000005004254',
#   'articleId': '0005004254',
#   'officeId': '014',
#   'officeName': '파이낸셜뉴스',
#   'title': '"한전 정말 정떨어집니다" 직원들에 10만원 상품권 줬다 뺏은 회사, 왜?',
#   'summary': '한국전력이 근로자의 날을 앞두고 직원들에게 10만원 상품권을 지급했다가 다시 회수해 논란이 되고 있다. 지난해 32조원 이상의 역대 최대 규모의 적자를 기록하고 올해도 1분기에만 5조원의 손실을 보자 상품권을 다시 ',
#   'serviceTime': 1682642702000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/014/2023/04/28/5004254.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88213rx9_000000000000000000015912',
#   'articleId': '0000015912',
#   'officeId': '648',
#   'officeName': '비즈워치',
#   'title': 'GS건설, 1분기 실적은…#베트남 #신사업 #성공적',
#   'summary': 'GS건설의 신사업 부문이 올 1분기 실적에서 강한 존재감을 드러냈다. GS건설의 핵심 사업인 건축·주택사업 다음으로 높은 매출액을 올리고 매출총이익률도 크게 상승했다. 베트남 첫 개발사업인 냐베 신도시 사업이 반영된',
#   'serviceTime': 1682642701000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/648/2023/04/28/15912.jpg',
#   'type': '1',
#   'sessionId': 'GdnMJkWbIlYg9EVZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880002EC_000000000000000000044092',
#   'articleId': '0000044092',
#   'officeId': '243',
#   'officeName': '이코노미스트',
#   'title': '“배달료 4000원으로 올려달라”…배민 기사들, 어린이날 배달 안 한다',
#   'summary': '배달의민족 배달 기사 ‘배민 라이더’들이 어린이날인 다음달 5일 하루 동안 파업하기로 결정했다. 이들은 9년째 동결 중인 기본 배달료를 3000원에서 4000원으로 인상해줄 것을 요구하고 있다. 27일 민주노총 서비',
#   'serviceTime': 1682642701000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/243/2023/04/28/44092.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000BF_000000000000000001738794',
#   'articleId': '0001738794',
#   'officeId': '057',
#   'officeName': 'MBN',
#   'title': "'SG 사태' 나흘째 하한가…금융위, 주가조작 세력 압수수색",
#   'summary': "무더기 하한가로 시작된 'SG증권' 사태가 주가조작 범죄로 새로운 국면을 맞고 있습니다. 특정 세력이 사전에 가격을 모의해 주식을 사고파는 방식으로 주가를 띄워오다 터졌다는 것인데, 금융위가 어제(27일) 이 세력의",
#   'serviceTime': 1682642701000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/057/2023/04/28/1738794.jpg',
#   'type': '2',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800010E_000000000000000002136562',
#   'articleId': '0002136562',
#   'officeId': '016',
#   'officeName': '헤럴드경제',
#   'title': '위메프, 5월내 회사 나가면 석달치 월급 준다',
#   'summary': '위메프가 5월 내 퇴사 시 특별 보상금을 주는 ‘이직 지원 제도’를 전 직원 대상으로 운영한다. 글로벌 커머스 기업이 위메프를 인수하고 본격적으로 경영 관리에 들어갔다는 분석이다. 28일 위메프는 전날 오전 사내에 ',
#   'serviceTime': 1682642646000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/016/2023/04/28/2136562.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800010E_000000000000000002136561',
#   'articleId': '0002136561',
#   'officeId': '016',
#   'officeName': '헤럴드경제',
#   'title': '‘SG증권 사태’ 종목들, 드디어 하한가 탈출…큰 낙폭 속 일부는 ↑ [투자360]',
#   'summary': '외국계 증권사 소시에테제네랄(SG)증권발(發) 매물로 인해 연일 급락세를 탔던 종목들이 28일 하한가에서 벗어났다. 이날 한국거래소에 따르면 오전 9시 3분 현재 대성홀딩스와 선광은 전 거래일보다 각각 26.04%,',
#   'serviceTime': 1682642642000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/016/2023/04/28/2136561.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000114_000000000000000011474796',
#   'articleId': '0011474796',
#   'officeId': '056',
#   'officeName': 'KBS',
#   'title': '동시다발 압수수색…속도 내는 ‘주가조작’ 의혹 수사',
#   'summary': "특정 종목의 무더기 하한가 사태 '주가 조작' 수사가 속도를 내고 있습니다. 앞서 관계자들에 대한 출국금지 조처가 내려진 데 이어 어제 금융당국이 관련 업체들에 대한 압수수색을 진행했습니다. 투자자들은 주가조작 의혹",
#   'serviceTime': 1682642617000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/056/2023/04/28/11474796.jpg',
#   'type': '2',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D6_000000000000000000743640',
#   'articleId': '0000743640',
#   'officeId': '031',
#   'officeName': '아이뉴스24',
#   'title': '파파이스, 안양일번가점 오픈…강남점 이후 6번째',
#   'summary': '파파이스가 오는 5월 2일 경기도 안양시 만안구 안양동에 신규 매장 ‘안양일번가점’을 오픈한다고 28일 밝혔다. 안양일번가점은 2월 성남신흥점에 이어 두 번째 경기도 지역 파파이스 매장이며, 지난해 12월 강남점 이',
#   'serviceTime': 1682642581000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/031/2023/04/28/743640.jpg',
#   'type': '1',
#   'sessionId': 'ZBVwG4TS9SD2LQyZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000F1_000000000000000002303900',
#   'articleId': '0002303900',
#   'officeId': '123',
#   'officeName': '조세일보',
#   'title': '3월 생산·소비 늘고, 투자 줄어…경기 불확실성 여전',
#   'summary': "지난달 산업생산과 소비가 증가세를 이어갔으나 투자는 하락했다. 통계청이 28일 발표한 '산업활동동향'에 따르면 지난 3월 전(全)산업 생산(계절조정·농림어업 제외)은 전달보다 1.6% 증가했다. 이러한 상승폭은 지난",
#   'serviceTime': 1682642581000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/123/2023/04/28/2303900.jpg',
#   'type': '1',
#   'sessionId': 'yzuMcW5YXT9zIcmZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D6_000000000000000000743638',
#   'articleId': '0000743638',
#   'officeId': '031',
#   'officeName': '아이뉴스24',
#   'title': '디아이씨, 美 중심 공급망 재편…매출 확대 기대-KB',
#   'summary': 'KB증권은 28일 디아이씨에 대해 미국 중심의 공급망 재편으로 전동화 부품 매출 확대가 기대된다고 밝혔다. 목표주가와 투자의견은 따로 제시하지 않았다. 디아이씨는 다년간 축적된 기술로 자동차 부품·중장비 부품으로 생',
#   'serviceTime': 1682642521000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/031/2023/04/28/743638.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000108_000000000000000004184466',
#   'articleId': '0004184466',
#   'officeId': '011',
#   'officeName': '서울경제',
#   'title': '우리산업, 전기차 열관리 부품 3종 세트로 퀀텀점프 시작',
#   'summary': '전기차 시스템 시장의 개화로 전기차 열관리 시스템의 역활 확장 및 기술 고도화로 부품시장도 고성장 전망된다. 동사는 테슬라 모델 S와 모델X에 PTC히터 납품 업체로 크게 관심을 받았으나, 테슬라가 대중 모델인 모델',
#   'serviceTime': 1682642521000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/011/2023/04/28/4184466.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D6_000000000000000000743637',
#   'articleId': '0000743637',
#   'officeId': '031',
#   'officeName': '아이뉴스24',
#   'title': "코스피, 美증시 강세에 상승 출발…개인 나홀로 '사자'",
#   'summary': '국내 증시가 미국 증시의 강세에 상승 출발하며 2500선을 탈환했다. 29일 오전 9시 10분 기준 코스피는 전일 대비 5.60포인트(0.22%) 오른 2501.41에 거래되고 있다. 개인이 1천699억원을 사들이고',
#   'serviceTime': 1682642461000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/031/2023/04/28/743637.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000C2_000000000000000004881067',
#   'articleId': '0004881067',
#   'officeId': '008',
#   'officeName': '머니투데이',
#   'title': "'위로 3개층 더 올린다' 수직증축 리모델링 2호 탄생",
#   'summary': '대치1차현대, 기존 15층에서 18층으로…수직증축 리모델링 최종 통과 서울 강남구 대치1차현대 아파트가 수직증축 리모델링 심의를 최종 통과했다. 수직증축은 기존 아파트에 층수를 더 올려 수직으로 늘리는 리모델링 방식',
#   'serviceTime': 1682642404000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/008/2023/04/28/4881067.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '08138263_000000000000000006775931',
#   'articleId': '0006775931',
#   'officeId': '421',
#   'officeName': '뉴스1',
#   'title': "SSG닷컴, 호주축산공사와 손잡고 '쇠고기' 최대 50% 행사",
#   'summary': 'SSG닷컴은 다음달 3일까지 호주축산공사와 협업 행사를 진행했다고 28일 밝혔다. 호주산 쇠고기 정육 인기상품을 엄선해 최대 50% 할인한 가격에 판매한다. 대표 상품으로 안심 스테이크(150g), 채끝 스테이크(3',
#   'serviceTime': 1682642402000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/421/2023/04/28/6775931.jpg',
#   'type': '1',
#   'sessionId': 'W2NGHBjZJpp9EGDB',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880002EC_000000000000000000044091',
#   'articleId': '0000044091',
#   'officeId': '243',
#   'officeName': '이코노미스트',
#   'title': '코빗, ‘돌고래유괴단’이 만든 배우 마동석 유튜브 광고 공개',
#   'summary': '암호화폐(가상자산) 거래소 코빗이 영화배우 마동석이 출연한 새로운 광고를 자사 및 광고 제작사인 돌고래유괴단의 공식 유튜브 채널에 공개했다고 28일 밝혔다. 이번에 선보인 코빗의 광고는 마동석 유니버스(세계관)를 재',
#   'serviceTime': 1682642401000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/243/2023/04/28/44091.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D6_000000000000000000743636',
#   'articleId': '0000743636',
#   'officeId': '031',
#   'officeName': '아이뉴스24',
#   'title': '서울 개별공시지가 14년만에 하락 전환…전년比 5.56% ↓',
#   'summary': '서울시의 올해 개별공시지가가 지난해 대비 5.56% 떨어진 것으로 나타났다. 2009년 이후 14년 만에 하락 전환됐다. 시는 올해 개별지 86만6천912필지의 공시지가를 28일 결정·공시한다고 밝혔다. 지난해 금리',
#   'serviceTime': 1682642401000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/031/2023/04/28/743636.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000EA_000000000000000003094967',
#   'articleId': '0003094967',
#   'officeId': '030',
#   'officeName': '전자신문',
#   'title': '[ET라씨로] 주식 거래 재개한 KG모빌리티, 장 초반 21% ↑',
#   'summary': "ET라씨로는 인공지능(AI) 기반으로 선별·분석한 주식 정보와 종목 매매 신호를 제공하는 전자신문 증권 정보 애플리케이션입니다. 플레이스토어에서 'ET라씨로'(->바로가기)를 다운로드하면 IT기업 뉴스와 시장 현황,",
#   'serviceTime': 1682642341000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/030/2023/04/28/3094967.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000107_000000000000000004838418',
#   'articleId': '0004838418',
#   'officeId': '015',
#   'officeName': '한국경제',
#   'title': 'DL이앤씨 1분기 매출 1조 8501억…신규 수주 3조 2762억',
#   'summary': 'DL이앤씨는 28일 지난 1분기 연결기준 매출이 1조 8501억원, 영업이익 902억원으로 잠정 집계됐다고 공시했다. 1분기 매출은 전년동기 대비 22% 증가했다. 영업이익은 28% 감소했다. 원자재 가격이 높은 수',
#   'serviceTime': 1682642341000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/015/2023/04/28/4838418.jpg',
#   'type': '1',
#   'sessionId': '4pxDrr0JcoLLkIYg',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8812805E_000000000000000000916767',
#   'articleId': '0000916767',
#   'officeId': '417',
#   'officeName': '머니S',
#   'title': '"퇴사하고 치킨집 차리려 했는데" 가맹점 \'치킨게임\'에 월매출 \'뚝\'',
#   'summary': "대출 전문 핀테크 기업 '핀다'가 상권 분석 플랫폼 '오픈업'을 통해 전국 치킨 프랜차이즈 가맹점 현황을 분석한 결과 치킨집 월평균 매출은 신종 코로나바이러스 감염증(코로나19) 이전보다 감소한 것으로 나타났다. 2",
#   'serviceTime': 1682642312000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/417/2023/04/28/916767.jpg',
#   'type': '1',
#   'sessionId': 'GdnMJkWbIlYg9EVZ',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000149_000000000000000001098365',
#   'articleId': '0001098365',
#   'officeId': '215',
#   'officeName': '한국경제TV',
#   'title': "SH공사, '씨드큐브 창동' 오피스 임대 공급",
#   'summary': "서울주택도시공사(이하 SH공사)가 창동 창업·문화산업단지에 '씨드큐브 창동' 프라임급 임대 오피스를 공급한다. SH공사는 '씨드큐브 창동' 임대 오피스 8~16층, 연면적 2만 9,914㎡를 층 단위·구역별로 공급한",
#   'serviceTime': 1682642264000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/215/2023/04/28/1098365.jpg',
#   'type': '1',
#   'sessionId': '1JHa1PAyWZ1ph47V',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011830001',
#   'articleId': '0011830001',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': '이창양 "美 반도체법 \'기업 부담\' 최소화…가드레일 등 지속 협의"',
#   'summary': '기사내용 요약 美 상무부 장관 만나 우리 기업 의견 전해 "10월 반도체 포괄허가 종료 우려 커…조치 요청" [세종=뉴시스]손차민 기자 = 윤석열 대통령이 국빈 방미 중인 가운데, 한미 정부가 미국 반도체지원법(CH',
#   'serviceTime': 1682642237000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/28/11830001.jpg',
#   'type': '1',
#   'sessionId': '1JHa1PAyWZ1ph47V',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005474304',
#   'articleId': '0005474304',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': '"독일, 중국에 반도체 제조용 화학물질 수출 제한 논의"',
#   'summary': '독일이 중국에 반도체 제조용 화학물질 수출을 제한하려는 움직임을 보이고 있다. 중국의 ‘반도체 굴기’를 견제하는 동시에 자국 반도체 산업을 보호하려는 의도로 파악된다. 지난해 슈바르츠하이데 바스프 공장 건설현장을 찾',
#   'serviceTime': 1682642222000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/28/5474304.jpg',
#   'type': '1',
#   'sessionId': '1JHa1PAyWZ1ph47V',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880003A5_000000000000000000043759',
#   'articleId': '0000043759',
#   'officeId': '293',
#   'officeName': '블로터',
#   'title': '대웅제약, 미국에 자가면역질환 신약 후보물질 수출한다',
#   'summary': "대웅제약이 미국 시장에 자가면역질환 신약 후보물질을 수출한다. 대웅제약은 이달 27일(현지시간) 미국 보스턴에서 열린 '한·미 디지털·바이오헬스 비즈니스 포럼'에서 미국 생명공학 투자 회사 애디텀 바이오의 자회사 비",
#   'serviceTime': 1682642221000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/293/2023/04/28/43759.jpg',
#   'type': '1',
#   'sessionId': '1JHa1PAyWZ1ph47V',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000385_000000000000000005252198',
#   'articleId': '0005252198',
#   'officeId': '277',
#   'officeName': '아시아경제',
#   'title': "희비 갈린 美대표기업…아마존 '흑자전환' vs 인텔 '사상 최대 손실'",
#   'summary': '미국 전자상거래와 반도체 부문을 대표하는 아마존과 인텔의 실적 희비가 갈렸다. 전자상거래 기업 아마존은 시장 예상을 훌쩍 뛰어넘는 성적을 올린 반면 인텔은 4조원에 육박하는 사상 최대 손실을 냈다. 27일(현지시간)',
#   'serviceTime': 1682642171000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/277/2023/04/28/5252198.jpg',
#   'type': '1',
#   'sessionId': 'OuT04epdoJFNmw3D',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000AD_000000000000000002797607',
#   'articleId': '0002797607',
#   'officeId': '029',
#   'officeName': '디지털타임스',
#   'title': '28개월만에 화려하게 복귀한 KG모빌리티...한때 상한가 근접',
#   'summary': 'KG모빌리티로 옷을 갈아입은 쌍용자동차가 화려하게 증시로 복귀했다. 기업회생절차로 2년 4개월 동안 주권 거래가 중단됐던 KG모빌리티가 재개 첫날인 28일 한때 가격제한폭에 근접하게 올랐다. 이날 오전 9시30분 현',
#   'serviceTime': 1682642168000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/029/2023/04/28/2797607.jpg',
#   'type': '1',
#   'sessionId': 'OuT04epdoJFNmw3D',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005474302',
#   'articleId': '0005474302',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': '한미 ‘반도체법, IRA 관련 기업투자 불확실성 최소화’ 합의',
#   'summary': '한미 산업·통상당국은 반도체지원법 및 인플레이션감축법(IRA)을 집중 논의하고 ‘기업 불확실성과 경영부담을 최소화’하기로 합의했다. 이창양 산업통상자원부 장관과 지나 러몬드 미국 에너지부 장관이 27일(현지시간) 미',
#   'serviceTime': 1682642161000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/28/5474302.jpg',
#   'type': '1',
#   'sessionId': 'OuT04epdoJFNmw3D',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005474301',
#   'articleId': '0005474301',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': 'HMM·삼성重 등 4개사, ‘선박 탄소 포집·액화저장 기술’ 확보에 맞손',
#   'summary': '국내 조선·해운 등 4개 회사가 해운업계 탄소 저감 국산 기술 확보를 위해 힘을 모은다. HMM(011200)·삼성중공업(010140)·파나시아·한국선급 등 4사는 지난 27일 선박 이산화탄소 포집·액화 저장 기술(',
#   'serviceTime': 1682642110000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/28/5474301.jpg',
#   'type': '1',
#   'sessionId': 'OuT04epdoJFNmw3D',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800010E_000000000000000002136554',
#   'articleId': '0002136554',
#   'officeId': '016',
#   'officeName': '헤럴드경제',
#   'title': '2년 4개월 만에 거래 재개된 KG모빌리티, 첫날 상한가 터치하나 [투자360]',
#   'summary': '지난 2년 4개월 동안 기업회생절차로 주권 거래가 중단됐던 KG모빌리티(옛 쌍용차)가 거래 재개 첫날인 28일 가격제한폭에 근접하게 올랐다. 이날 오전 9시 20분 현재 코스피 시장에서 KG모빌리티는 시초가 대비 2',
#   'serviceTime': 1682642101000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/016/2023/04/28/2136554.jpg',
#   'type': '1',
#   'sessionId': 'OuT04epdoJFNmw3D',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000107_000000000000000004838414',
#   'articleId': '0004838414',
#   'officeId': '015',
#   'officeName': '한국경제',
#   'title': '에코프로 "605억 규모 CB 직접 취득해 소각"…주가 6%대 \'상승\'',
#   'summary': '에코프로의 주가가 강세를 보이고 있다. 과거 발행한 전환사채에 대해 콜옵션을 행사해 자기사채로 취득 후 소각하기로 결정하자 투자심리가 개선된 것으로 풀이된다. 28일 오전 9시 30분 기준 에코프로는 전일 대비 4만',
#   'serviceTime': 1682642059000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/015/2023/04/28/4838414.jpg',
#   'type': '1',
#   'sessionId': 'tWhUsiA8JwnAFLJ9',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8812A0A8_000000000000000002707634',
#   'articleId': '0002707634',
#   'officeId': '119',
#   'officeName': '데일리안',
#   'title': '시몬스 침대, 동종업계 이직한 전 직원 대상 가처분 소송 제기',
#   'summary': '시몬스 침대가 지난 1월 퇴사 후 일룸 슬로우베드로 이직한 전 직원 A씨를 상대로 최근 서울중앙지방법원에 전직금지 가처분 신청서를 제출했다. 시몬스는 회사의 핵심 기술과 직결된 생산 및 R&D(연구개발) 관련 부서에',
#   'serviceTime': 1682642043000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/119/2023/04/28/2707634.jpg',
#   'type': '1',
#   'sessionId': 'tWhUsiA8JwnAFLJ9',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000C2_000000000000000004881062',
#   'articleId': '0004881062',
#   'officeId': '008',
#   'officeName': '머니투데이',
#   'title': "'광명자이더샵포레나' 견본주택 29일 개관…809가구 일반분양",
#   'summary': "GS건설 컨소시엄이 경기도 광명시 광명동 9-8번지 일대에서 분양하는 '광명자이더샵포레나'의 견본주택을 오는 29일 개관한다. 광명1R 재정비 촉진지구를 재개발해 공급하는 이 단지는 지하 3층~지상 최고 38층, 2",
#   'serviceTime': 1682642012000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/008/2023/04/28/4881062.jpg',
#   'type': '1',
#   'sessionId': 'fzu5cOkWj5eHDRW2',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8811AD97_000000000000000000333638',
#   'articleId': '0000333638',
#   'officeId': '374',
#   'officeName': 'SBS Biz',
#   'title': '아마존, 1분기 실적 예상치 상회…주가 변동성 커져',
#   'summary': '세계 최대 전자상거래 업체 아마존이 현지시간 27일 월가의 예상을 상회하는 1분기 실적을 발표했습니다. 아마존은 지난 1∼3월 1천 274억 달러(170조 9천 708억 원)의 매출을 기록했다고 이날 밝혔습니다. 이',
#   'serviceTime': 1682641997000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/374/2023/04/28/333638.jpg',
#   'type': '1',
#   'sessionId': 'tWhUsiA8JwnAFLJ9',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
# ...
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000FF_000000000000000005004224',
#   'articleId': '0005004224',
#   'officeId': '014',
#   'officeName': '파이낸셜뉴스',
#   'title': '美의 대중국 첨단산업 투자 제한에 中 "차별적 관행"',
#   'summary': '미국이 중국 첨단 산업에 대한 투자를 제한할 것이라는 보도에 대해 중국 정부는 “특정 국가별 차별적 관행은 국제경제무역의 기본 원칙에 위배된다”면서 “단호히 반대한다”고 밝혔다. 28일 중국 상무부에 따르면 수줴팅 ',
#   'serviceTime': 1682640076000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/014/2023/04/28/5004224.jpg',
#   'type': '1',
#   'sessionId': '9mkkqhdJEoQCxr8j',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880002EC_000000000000000000044088',
#   'articleId': '0000044088',
#   'officeId': '243',
#   'officeName': '이코노미스트',
#   'title': '인천공항免 ‘10년 사업권’ 땄다…‘신라·신세계·현대百’ 저주 없는 승자 될까',
#   'summary': '10년 사업권이 걸린 인천공항 면세점 운영자가 26~27일 이틀에 걸쳐 발표됐다. 가장 경쟁이 치열했던 주류·담배 사업구역(DF 1·2) 중 1구역은 호텔신라, 2구역은 신세계디에프가 운영하게 된다. 패션·액세서리 ',
#   'serviceTime': 1682640072000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/243/2023/04/28/44088.jpg',
#   'type': '1',
#   'sessionId': '9mkkqhdJEoQCxr8j',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000108_000000000000000004184434',
#   'articleId': '0004184434',
#   'officeId': '011',
#   'officeName': '서울경제',
#   'title': 'MZ 워너비 지식산업센터, ‘덕은 DMC 아이에스 비즈타워 한강’',
#   'summary': 'MZ세대를 중심으로 ‘워라벨’ 문화가 확산되고 있다. 부동산 시장도 MZ세대의 특성을 고려한 특화설계를 통해 경쟁력 강화에 나서고 있는 모습이다. MZ세대는 물질적 보상보다는 개인적 시간의 확보를 선호하는 경향이 강',
#   'serviceTime': 1682640068000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/011/2023/04/28/4184434.jpg',
#   'type': '1',
#   'sessionId': '9mkkqhdJEoQCxr8j',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88127058_000000000000000000897500',
#   'articleId': '0000897500',
#   'officeId': '366',
#   'officeName': '조선비즈',
#   'title': '포스코, 철강·리튬 부산물로 도자기 소재 개발',
#   'summary': '포스코는 경기 이천시, 한국세라믹기술원과 ‘도자기 분야 소재공급 협력체제 구축을 위한 업무협약’을 체결했다고 27일 밝혔다. 협약에 따라 포스코는 고로(용광로)에서 쇳물을 생산하면서 나오는 수재 슬래그를 비롯한 제철',
#   'serviceTime': 1682640067000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/366/2023/04/28/897500.jpg',
#   'type': '1',
#   'sessionId': 'k0nbXxDrV35OXS9H',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000108_000000000000000004184433',
#   'articleId': '0004184433',
#   'officeId': '011',
#   'officeName': '서울경제',
#   'title': '가재지구 제일풍경채 브랜드타운의 시작 제일건설 ‘지제역 제일풍경채 제일풍경채 2BL’ 5월 분양',
#   'summary': "삼성전자 평택캠퍼스 바로 옆 배후주거지로 주목받고 있는 '가재지구'가 대규모 '제일풍경채' 브랜드타운으로 변모한다. 제일건설㈜은 5월 가재지구 공동2블록에 조성되는 '지제역 반도체밸리 제일풍경채 2BL' 1,152세",
#   'serviceTime': 1682640063000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/011/2023/04/28/4184433.jpg',
#   'type': '1',
#   'sessionId': '9mkkqhdJEoQCxr8j',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '08138260_000000000000000000341043',
#   'articleId': '0000341043',
#   'officeId': '437',
#   'officeName': 'JTBC',
#   'title': '네쌍둥이 낳자…정장 입고 직원 집 찾아간 포스코 회장님｜비즈니스 클라스',
#   'summary': "이어서 매주 금요일, 따끈따끈한 경제계 소식과 소비자 정보를 전해드리는 코너, '비즈니스클라스' 경제산업부 정원석 기자 나와 있습니다. 첫번째 소식 뭔가요? 네, 제가 오늘(28일) 과자를 하나 갖고 나왔는데, 너무",
#   'serviceTime': 1682640061000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/437/2023/04/28/341043.jpg',
#   'type': '2',
#   'sessionId': '9mkkqhdJEoQCxr8j',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880002EC_000000000000000000044086',
#   'articleId': '0000044086',
#   'officeId': '243',
#   'officeName': '이코노미스트',
#   'title': '‘한화오션’ 내달 출범…대우조선해양, 굴곡의 역사 끝낼까',
#   'summary': '공정거래위원회가 한화와 대우조선해양의 기업 결합에 대해 조건부 승인 결정을 내렸다. 20년 넘는 세월 동안 10조원 넘는 ‘혈세’로 연명해 온 대우조선이 한화그룹 품에서 재도약할 수 있을지 관심이 쏠린다. 대우조선은',
#   'serviceTime': 1682640061000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/243/2023/04/28/44086.jpg',
#   'type': '1',
#   'sessionId': '9mkkqhdJEoQCxr8j',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000149_000000000000000001098353',
#   'articleId': '0001098353',
#   'officeId': '215',
#   'officeName': '한국경제TV',
#   'title': '투자은행 번스타인 "암호화폐 랠리 지속 예상...비트코인 매수 기회는 지금"',
#   'summary': '비트코인 가격이 올해 들어 80% 가까이 급등한 가운데 글로벌 투자은행 번스타인이 비트코인 강세론을 주장하고 나섰다. 27일(현지시간) CNBC에 따르면 번스타인은 "미국 실리콘밸리은행(SVB) 파산 후폭풍이 지속됨',
#   'serviceTime': 1682640054000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/215/2023/04/28/1098353.jpg',
#   'type': '1',
#   'sessionId': '9mkkqhdJEoQCxr8j',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000108_000000000000000004183933',
#   'articleId': '0004183933',
#   'officeId': '011',
#   'officeName': '서울경제',
#   'title': '정부, ‘전세사기 특별법’ 제정…피해자에 우선매수권·생계비 지원',
#   'summary': '정부가 ‘전세사기 특별법’ 제정을 추진한다. 특별법 제정시 전세사기 피해자는 거주 주택의 우선매수권을 받는다. 특별법에는 한국토지주택공사(LH)가 전세사기 피해 주택을 매입해 공공임대로 공급하는 방안도 담겼다. 정부',
#   'serviceTime': 1682557268000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/011/2023/04/27/4183933.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88127058_000000000000000000897103',
#   'articleId': '0000897103',
#   'officeId': '366',
#   'officeName': '조선비즈',
#   'title': '경매 넘어가고 수사 시작해야 ‘전세사기’ 인정… 우선매수권 등 특별법 2년간 유효',
#   'summary': '‘깡통전세’는 전세사기 피해자 아냐 6가지 요건 충족해야 특례 지원받는다 우선매수권 부여·조세채권 안분·낙찰자금 지원 공공매입으로 ‘先 보상 後 구상’ 방안은 제외 ‘긴급복지’ 지원 병행… 月 생계비 62만원 지급 ',
#   'serviceTime': 1682557267000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/366/2023/04/27/897103.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000CE_000000000000000001209523',
#   'articleId': '0001209523',
#   'officeId': '082',
#   'officeName': '부산일보',
#   'title': '6개 조건 충족해야 전세사기 피해자…경매진행·서민임차주택 등',
#   'summary': '전세사기 피해자로 인정돼 특별법에 따른 지원을 받으려면 확정일자 받은 세입자, 경매·공매 진행, 다수 피해자가 발생할 우려 등 6가지의 요건을 모두 갖춰야 한다. 이들 피해자에게는 살던 주택 우선매수권을 제공하거나 ',
#   'serviceTime': 1682557265000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/082/2023/04/27/1209523.jpg',
#   'type': '1',
#   'sessionId': '0fFMBk04RgIZeL8v',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000BC_000000000000000005122432',
#   'articleId': '0005122432',
#   'officeId': '009',
#   'officeName': '매일경제',
#   'title': '두산건설, 서울 새 아파트 ‘새절역 두산위브 트레지움’ 내달 공급',
#   'summary': '서울 아파트 청약시장 분위기가 반전 양상을 보이고 있다. 지난해 4분기 평균 5.9대 1에 불과하던 1순위 청약 경쟁률은 올해 1분기 평균 54.1대 1로 10배 이상 뛰었기 때문이다. 사업장마다 계약률도 빠르게 오',
#   'serviceTime': 1682557263000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/009/2023/04/27/5122432.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800006B_000000000000000003219995',
#   'articleId': '0003219995',
#   'officeId': '032',
#   'officeName': '경향신문',
#   'title': '‘전세사기 피해자’, 낙찰 또는 공공임대만 선택할 수 있다',
#   'summary': '‘전세사기 피해자’로 인정받은 사람은 현재 거주하고 있는 피해주택에 대한 우선매수권이 부여된다. 낙찰받기를 원치 않지만 현재 사는 곳에서 거주하기를 희망하는 전세사기 피해자는 한국토지주택공사(LH)에 우선매수권을 넘',
#   'serviceTime': 1682557261000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/032/2023/04/27/3219995.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000BC_000000000000000005122431',
#   'articleId': '0005122431',
#   'officeId': '009',
#   'officeName': '매일경제',
#   'title': '이익 90% 증가한 두산밥캣, 신고가 질주',
#   'summary': '올해 주가 44% 올라 1분기 호실적을 기록한 두산밥캣 주가가 상승세를 지속하며 신고가를 기록했다. 27일 한국거래소에 따르면 오전 9시 30분 기준 두산밥캣 주가는 6.13% 상승한 5만200원에 거래 중이다. 5',
#   'serviceTime': 1682557261000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/009/2023/04/27/5122431.jpg',
#   'type': '1',
#   'sessionId': 'nGMkV4bosihcMgUW',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88156f75_000000000000000000736345',
#   'articleId': '0000736345',
#   'officeId': '469',
#   'officeName': '한국일보',
#   'title': "'곰표' 뗀 대표 밀맥주, 호랑이 앞세워 CU에서 단독 판매…흥행 대박 이어갈까",
#   'summary': "곰 캐릭터 대신 호랑이 캐릭터를 앞세웠다. 하지만 앞서 품절 대란을 일으켰던 '곰표 밀맥주'와 맛은 똑같다. 26일 편의점 CU를 운영하는 BGF리테일은 수제맥주 기업 세븐브로이가 CU를 통해 28일부터 '대표 밀맥",
#   'serviceTime': 1682557261000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/469/2023/04/27/736345.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000FF_000000000000000005003534',
#   'articleId': '0005003534',
#   'officeId': '014',
#   'officeName': '파이낸셜뉴스',
#   'title': '"개미 떠나고, 인건비는 비싸" 日노무라 3년째 실적 부진',
#   'summary': '일본 최대 금융지주사인 노무라홀딩스가 3년 연속 부진한 실적을 발표했다. 글로벌 인플레이션과 금리 상승으로 개인 주식거래가 침체된 데다 내부적으로는 높은 인건비 등이 발목을 잡은 것으로 풀이된다. 27일 현지 금융투',
#   'serviceTime': 1682557207000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/014/2023/04/27/5003534.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8800010E_000000000000000002136003',
#   'articleId': '0002136003',
#   'officeId': '016',
#   'officeName': '헤럴드경제',
#   'title': '‘먼지에 진심인 다이슨’…전세계 3만4000명에게 ‘청소 습관’ 물었다',
#   'summary': '다이슨이 전세계 사람들의 청소 습관 및 행동을 분석한 ‘글로벌 먼지 연구(Global dust study)’ 연례 결과를 발표했다고 27일 밝혔다. 이번 연구는 한국을 포함한 총 39개국 약 3만3997명을 대상으로',
#   'serviceTime': 1682557206000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/016/2023/04/27/2136003.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8811AD97_000000000000000000333407',
#   'articleId': '0000333407',
#   'officeId': '374',
#   'officeName': 'SBS Biz',
#   'title': "눈병까지 온다…'최강 전파력' 코로나 새 변이 국내만 152건",
#   'summary': "인도를 중심으로 빠르게 확산 중인 코로나 XBB.1.16 변이가 이미 국내에도 유입된 것으로 파악됐습니다. 이 변이는 이전 변이에서 보기 어려웠던 '눈병 증상'이 나타난다고 알려졌습니다. 임숙영 중앙방역대책본부(방대",
#   'serviceTime': 1682557201000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/374/2023/04/27/333407.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000C2_000000000000000004880344',
#   'articleId': '0004880344',
#   'officeId': '008',
#   'officeName': '머니투데이',
#   'title': "전세 피해자 전용 대출 나온다...'신혼부부 최우대' 적용",
#   'summary': "6가지 기준 충족해야만 정부 지원 정부가 다음 달 '전세사기 피해자 전용 디딤돌 대출'(주택기금 구입자금대출)을 내놓는다. 대출 한도를 1억5000만원 이상 올리고 금리도 1%대 초저금리로 제공한다는 방침이다. 이 ",
#   'serviceTime': 1682557200000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/008/2023/04/27/4880344.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011827140',
#   'articleId': '0011827140',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': '피해자들에 3%대 특례보금자리론…LTV 낙찰가 100%[전세사기대책]',
#   'summary': '기사내용 요약 특례보금자리론 연 3.65~3.95% 적용 LTV 낙찰가 100%·일반주담대는 80% DSR·DTI 적용 제외…연체정보 유예 3%대 신용대출, 1200만원 한도 지원 [서울=뉴시스] 정옥주 기자 = 금',
#   'serviceTime': 1682557200000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/27/11827140.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '08138263_000000000000000006773080',
#   'articleId': '0006773080',
#   'officeId': '421',
#   'officeName': '뉴스1',
#   'title': '전세 피해자에 우선매수권…공공 매입땐 소득 조건없이 입주(종합)',
#   'summary': '정부가 전세사기 피해자 지원을 위한 한시 특별법을 마련했다. 정해진 6개 요건을 모두 충족해야 특별법에 따른 우선매수권 행사나 지원을 받을 수 있다. 전세사기 피해자는 우선매수권으로 거주 주택을 매입하거나 공공임대 ',
#   'serviceTime': 1682557200000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/421/2023/04/27/6773080.jpg',
#   'type': '1',
#   'sessionId': '4YVh0Sb0J9YEfurt',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011827137',
#   'articleId': '0011827137',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': "피해자에 '우선매수권'…경·공매 낙찰시 금융·세제 지원도[전세사기 대책]",
#   'summary': "기사내용 요약 임차인들에 직접 경매 유예·정지 신청 권한 부여 경매시 임차인에 우선매수권 부여…LH 양도 가능 '조세채권 안분'도 포함…모든 부동산에 채권 배분 [서울=뉴시스] 고가혜 기자 = 정부가 내놓은 전세사기",
#   'serviceTime': 1682557200000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/27/11827137.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000D8_000000000000000013906561',
#   'articleId': '0013906561',
#   'officeId': '001',
#   'officeName': '연합뉴스',
#   'title': '전세피해에 우선매수권·경매자금 전액대출…특별법 제정해 지원',
#   'summary': '취득세 면제·재산세 감면…LH, 주택 매입해 피해자에 임대 정부, 전세사기 피해 지원 방안 발표 피해가구에 생계비·주거비 지원도…특별법 2년간 유효 (서울=연합뉴스) 박초롱 기자 = 정부가 2년간 적용되는 한시적인 ',
#   'serviceTime': 1682557200000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/001/2023/04/27/13906561.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '88000127_000000000000000011827138',
#   'articleId': '0011827138',
#   'officeId': '003',
#   'officeName': '뉴시스',
#   'title': "'살던 집에 계속 살 수 있게'...LH가 매입해 공공임대한다[전세사기 대책]",
#   'summary': '기사내용 요약 \'전세사기 피해자 지원 및 주거안정방안\' 발표 LH, 피해자에 우선매수권 양도받아 경·공매 매입 소득·자산요건 안 따지고 매입임대 입주 자격 "전세보증금에 직접적 지원·보전은 없다" 강조 [서울=뉴시스',
#   'serviceTime': 1682557200000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/003/2023/04/27/11827138.jpg',
#   'type': '1',
#   'sessionId': 'y1weuz4AlyHbc9rM',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880002EC_000000000000000000044001',
#   'articleId': '0000044001',
#   'officeId': '243',
#   'officeName': '이코노미스트',
#   'title': '1분기 글로벌 IPO 건수·금액 모두 ↓…“유동성부족 당분간 견뎌야”',
#   'summary': '올해 1분기의 기업공개(IPO) 시장 여건은 한층 더 어려웠다. 기준금리 인상, 인플레이션, 글로벌 은행업계의 위기 등으로 투자자들이 미래 성장보다 현재 가치를 우선시하고 있어서다. EY는 이 같은 내용을 담은 ‘2',
#   'serviceTime': 1682557141000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/243/2023/04/27/44001.jpg',
#   'type': '1',
#   'sessionId': 'nGMkV4bosihcMgUW',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000E7_000000000000000005473130',
#   'articleId': '0005473130',
#   'officeId': '018',
#   'officeName': '이데일리',
#   'title': '예스티, 반도체 고압 어닐링 장비 국책과제 선정',
#   'summary': '반도체 장비 전문기업 예스티(122640)는 산업통상자원부가 주관하는 ‘차세대 지능형반도체 기술개발 사업’에 선정돼 반도체 구조결함 개선용 중수소 고압 어닐링 장비 개발을 추진한다고 27일 밝혔다. 예스티는 고압 어',
#   'serviceTime': 1682557087000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/018/2023/04/27/5473130.jpg',
#   'type': '1',
#   'sessionId': 'g570sybM1wS6NVN9',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '880000FF_000000000000000005003531',
#   'articleId': '0005003531',
#   'officeId': '014',
#   'officeName': '파이낸셜뉴스',
#   'title': '빵지순례하러 마트 간다... 맛집 버터빵, 소금빵 선보이는 이곳 어디야?',
#   'summary': "롯데마트가 MZ세대를 중심으로 인기가 증가하며, 하나의 문화로 자리매김한 디저트를 적극 공략한다. '빵지순례(빵+성지순례)'와 '디켓팅(디저트+티켓팅)'과 같은 신조어가 생겨날 정도로 인기가 높아지자 자체브랜드(PB",
#   'serviceTime': 1682557087000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/014/2023/04/27/5003531.jpg',
#   'type': '1',
#   'sessionId': 'nGMkV4bosihcMgUW',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'},
#  {'sectionId': '101',
#   'gdid': '8812805E_000000000000000000916412',
#   'articleId': '0000916412',
#   'officeId': '417',
#   'officeName': '머니S',
#   'title': "'배터리' 날개 단 삼성SDI, 1분기 매출 역대 최대… 영업익도 16.5% '껑충'",
#   'summary': '삼성SDI가 배터리를 다루는 에너지 부문 성장세에 힘입어 올해 1분기 실적 개선에 성공했다. 삼성SDI는 올해 1분기 매출 5조3548억원, 영업이익 3754억원을 기록했다고 27일 밝혔다. 지난해 1분기보다 매출이',
#   'serviceTime': 1682557085000,
#   'imageUrl': 'https://mimgnews.pstatic.net/image/origin/417/2023/04/27/916412.jpg',
#   'type': '1',
#   'sessionId': 'nGMkV4bosihcMgUW',
#   'modelVersion': 'news_sec_v2.0',
#   'airsServiceType': 'DEFAULT'}]

# %%
"""
Python 리스트(List)에 대해서, append()와 extend()는 둘 다 리스트에 새로운 요소를 추가하는 메소드이지만, 동작 방식에서 차이가 있습니다.
append() 메소드는 리스트의 끝에 하나의 요소를 추가합니다. 이 때 추가되는 요소는 리스트 형태로 들어올 필요가 없으며, 하나의 값(value)만 들어와도 됩니다.

예시:
my_list = [1, 2, 3]
my_list.append(4)
print(my_list) # [1, 2, 3, 4]

my_list.append([5, 6])
print(my_list) # [1, 2, 3, 4, [5, 6]]
extend() 메소드는 리스트 끝에 iterable(반복 가능한) 객체의 모든 항목을 추가합니다. 이 때 추가되는 항목들은 하나의 값으로 들어오지 않고, 요소 하나하나가 리스트의 형태로 들어와야 합니다.

예시:
my_list = [1, 2, 3]
my_list.extend([4, 5, 6])
print(my_list) # [1, 2, 3, 4, 5, 6]

my_list.extend("hello")
print(my_list) # [1, 2, 3, 4, 5, 6, 'h', 'e', 'l', 'l', 'o']
따라서, append() 메소드는 리스트에 요소를 추가할 때 리스트 자체를 하나의 요소로 추가할 수 있지만, extend() 메소드는 리스트에 요소를 추가할 때 iterable 객체의 모든 요소를 각각 추가합니다.
"""

# %%
df =
