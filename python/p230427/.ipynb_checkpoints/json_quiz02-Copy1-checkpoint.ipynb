# %%
"""
1 - 10page(200개) 뉴스 타이틀을 화면에 출력하기. 총 
- 출력 형태 :1. 타이틀 

"""


import requests
from bs4 import BeautifulSoup

# %%
url = "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101"
headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}

httpResponse = requests.get(url, headers = headers)
httpResponse.text
# Out:
# '\r\n\r\n\r\n\r\n<!DOCTYPE HTML>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="referrer" contents="always">\r\n<meta http-equiv="refresh" content="600" />\r\n<meta name="viewport" content="width=1106" />\r\n\r\n    \r\n    \r\n        \r\n            \r\n                \r\n                    \r\n                    \r\n                    \r\n                    \r\n                        \r\n\t                        \r\n\t\t                    \r\n\t\t                        \r\n\t\t                        \r\n\t\t                        \r\n\t\t                    \r\n\t\t                    \r\n\t\t                    \r\n\t\t                    \r\n\t\t                    \r\n\t\t                    \r\n\t\t                \r\n                    \r\n                    \r\n                \r\n            \r\n            \r\n            \r\n            \r\n            \r\n        \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n\r\n<meta property="og:title"       content="경제 : 네이버 뉴스">\r\n<meta property="og:type"        content="website">\r\n<meta property="og:url"         content="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101">\r\n<meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>\r\n<meta property="og:description" content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공">\r\n<meta property="og:article:author"\tcontent="네이버"/>\r\n\r\n<meta name="twitter:card"\t\tcontent="summary">\r\n<meta name="twitter:title"\t\tcontent="경제 : 네이버 뉴스">\r\n<meta name="twitter:site"       content="네이버 뉴스">\r\n<meta name="twitter:creator"    content="네이버 뉴스">\r\n<meta name="twitter:image"\t\tcontent="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\r\n<meta name="twitter:description" content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공">\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<title>경제 홈 : 네이버 뉴스\t</title>\r\n<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" />\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\r\n\r\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css"/>\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css"/>\n\t\t\n\t\t\n\t\n\t\n\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" charset="euc-kr"></script>\r\n\r\n\r\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" charset="utf-8"></script>\n\n\n\n\n\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\n\t\n\n\n\n\n\t\n\t\t\n\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n<script type="text/javascript">\nvar _MAIN_NEWS_MENU_ID=\'shm\';\nvar _MAIN_NEWS_SECTION_ID=\'103\';\nvar ccsrv=\'cc.naver.com\';\nvar g_ssc=\'news.sec\';\nwindow.nsc = g_ssc; \nvar gnb_service=\'news\';\nvar gnb_logout=encodeURIComponent(location.href);\nvar gnb_template=\'gnb_utf8\';\nvar gnb_brightness = 3;\nvar gnb_searchbox=\'on\';\nvar gnb_shortnick=\'on\';\n\nvar gnb_timestamp = "Thu Apr 27 15:15:33 KST 2023";\n</script>\n\n\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" charset="euc-kr"></script>\n\n\n\n\n\n\n\n\n    \n    \n        \n    \n\n<script>\n    \n    var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";\n    if (!isUnderIE10) {\n        var gladSDK = document.createElement("script");\n        gladSDK.async = true;\n        gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gf ...

# %%
soup = BeautifulSoup(httpResponse.text, "html.parser")
"""
동적인 웹 데이터 분석
# Json을 받아서 서치 하는 것
# crawling를 동적인 형태로 해요

"""
# Out:
# [<span class="cluster_head_sub_topic">삼성엔지니어링 1분기 영업이익 2254억원 </span>,
#  <span class="cluster_head_sub_topic">전년 동기 대비 29.2%↑ </span>,
#  <span class="cluster_head_sub_topic">美 트럼불 가스복합발전소 착공 </span>,
#  <span class="cluster_head_sub_topic">남부발전 </span>,
#  <span class="cluster_head_sub_topic">강남3구 아파트값 일제 상승 </span>,
#  <span class="cluster_head_sub_topic">노원도 68주 만에 올랐다 </span>,
#  <span class="cluster_head_sub_topic">구자열 무협 회장 </span>,
#  <span class="cluster_head_sub_topic">반도체법·IRA 우려 전달 </span>,
#  <span class="cluster_head_sub_topic">"전세사기 특별법" 2년간 적용 </span>,
#  <span class="cluster_head_sub_topic">피해자 주거권 보장 방점 </span>,
#  <span class="cluster_head_sub_topic">박지원 두산에너빌리티 회장 </span>,
#  <span class="cluster_head_sub_topic">글로벌 SMR 기업과 회동 </span>,
#  <span class="cluster_head_sub_topic">中 리오프닝 효과 작은 이유 </span>,
#  <span class="cluster_head_sub_topic">"IT 수요 회복 우선돼야" </span>,
#  <span class="cluster_head_sub_topic">금융위 주가조작 업체 압수수색 </span>,
#  <span class="cluster_head_sub_topic">임창정도 당한 SG사태 일파만파 </span>,
#  <span class="cluster_head_sub_topic">삼성SDI 1분기 영업이익 3754억원 </span>,
#  <span class="cluster_head_sub_topic">삼성SDI1분기 5.3조 매출·3754억 영업익 </span>,
#  <span class="cluster_head_sub_topic">국내 청정수소 생산인프라 확대한다 </span>,
#  <span class="cluster_head_sub_topic">산업부 수소생산기지 구축과제 공고 </span>,
#  <span class="cluster_head_sub_topic">포스코인터 1분기 영업익 2796억 </span>,
#  <span class="cluster_head_sub_topic">포스코인터내셔널 실적 선방 </span>,
#  <span class="cluster_head_sub_topic">삼성전자 </span>,
#  <span class="cluster_head_sub_topic">반도체 4.6조원 적자 </span>]
